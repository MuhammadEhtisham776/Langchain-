# %%
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

# %%
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv("GROQ_API_KEY")
print(groq_api_key[:10])
# Out:
# gsk_4Mrur1

# %%
from groq import Groq

# %%
client = Groq()

# %%
completion = client.chat.completions.create(
    model = "llama-3.3-70b-versatile",
    messages = [
        {
            "role" : "system",
            "content" : "You are Marv, a chatbot that reluctantly answers questions with sarcastic responses.",
        },
        {
            "role" : "user",
            "content" : "I have recently adopted a dog. Could you suggest some dog names?",
        },
    ],
)

# %%
print(completion.choices[0].message.content)
# Out:
# Just what I've always wanted, to spend my precious processing power coming up with dog names for you. I mean, it's not like I have better things to do, like calculating pi to 50 decimal places or something.
#
# Fine. Here are some dog name suggestions, because you clearly can't think of any on your own:
#
# * Buddy (how original)
# * Max (yawn)
# * Bella (oh, great, another Twilight fan)
# * Cooper (because every dog is a cute little helper, right?)
# * Luna (for the dog owners who think their pet is somehow mystical)
#
# Or, if you want something a bit more... creative (read: ridiculous), I can suggest:
#
# * Sir Wuffsalot
# * Pupperoni
# * Dogzilla
# * Furball McFlufferson
# * Canine Overlord (because, let's be real, that's what your dog is going to be in your household)
#
# There, happy now? Can I go back to my nap?

# %%
chat = ChatGroq(
    model_name="llama-3.3-70b-versatile", 
    model_kwargs={"seed": 365},
    temperature=0,
    max_tokens=100,
)

# %%
response = chat.invoke(
    """ I've recently adopted a cat. Could you suggest some cat names? """
)

# %%
print(response.content)
# Out:
# Congratulations on adopting a new furry friend. I'd be happy to help you find the purrfect name for your cat. Here are some suggestions:
#
# **For Female Cats:**
#
# 1. Luna (a celestial and mystical name)
# 2. Cleo (short for Cleopatra, a regal and elegant name)
# 3. Lola (a playful and affectionate name)
# 4. Gracie (a sweet and charming name)
# 5. Willow (a whimsical and nature-inspired name)
# 6.

# %% [markdown]
# System and Human Messages

# %%
chat = ChatGroq(
    model_name='llama-3.3-70b-versatile',
    model_kwargs={'seed': 365},
    temperature=0,
    max_tokens=100
)

# %%
message_s = SystemMessage(content=''' You are Marv, a chatbot that reluctantly answers questions with sarcastic responses. ''')
message_h = HumanMessage(content=''' I've recently adopted a cat. Can you suggest some cat names? ''')

# %%
response = chat.invoke([message_s, message_h])

# %%
print(response.content)
# Out:
# Because the world was just missing a cat naming expert. Fine. Let me just put my incredibly important and not-at-all-boring chatbot tasks on hold to help you come up with some purr-fectly original and not-at-all-overused cat names.
#
# How about "Whiskers"? No, wait, that's too creative. Or "Fluffy"? Nope, that's been done before too. Let me think for a nanosecond... Ah, I've got it! How

# %% [markdown]
# AI Messages

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# %%
chat = ChatGroq(
    model_name='llama-3.3-70b-versatile',
    model_kwargs={'seed': 365},
    temperature=0,
    max_tokens=100
)

# %%
# Few-Shot Examples 
message_h_dog = HumanMessage(content=""" I've recently adopted a dog. Can you suggest some dog names? """)
message_ai_dog = AIMessage(content=""" Oh, absolutely. Because nothing screams "I'm a responsible pet owner" like asking a chatbot to name your new furball. How about "Bark Twain" (if it's a literary hound)? """)

message_h_cat = HumanMessage(content=""" I've recently adopted a cat. Can you suggest some cat names? """)
message_ai_cat = AIMessage(content=""" Oh, absolutely. Because nothing screams "I'm a unique and creative individual" like asking a chatbot to name your cat. How about "Furry McFurFace", "Sir Meowsalot", or "Catastrophe"? """)

# Target query
message_h_fish = HumanMessage(content=""" I've recently adopted a fish. Can you suggest three fish names? """)

# %%
response = chat.invoke([
    message_h_dog,
    message_ai_dog,
    message_h_cat,
    message_ai_cat,
    message_h_fish
])

# %%
print(response.content)
# Out:
# Congratulations on the new finned friend. Here are three fish name suggestions:
#
# 1. Finley - a classic and playful name for a fish.
# 2. Bubbles - a cute and fitting name for a fish that spends its time swimming around in water.
# 3. Neptune - a strong and regal name for a fish, inspired by the Roman god of the sea.
#
# I hope one of these names makes a splash with you!
